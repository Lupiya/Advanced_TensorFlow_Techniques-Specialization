# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=800, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/800
# 614/614 [==============================] - 1s 1ms/sample - loss: 257.4610 - y1_output_loss: 120.6712 - y2_output_loss: 134.3515 - y1_output_root_mean_squared_error: 11.0372 - y2_output_root_mean_squared_error: 11.6465 - val_loss: 39.5902 - val_y1_output_loss: 19.2972 - val_y2_output_loss: 19.3181 - val_y1_output_root_mean_squared_error: 4.4397 - val_y2_output_root_mean_squared_error: 4.4587
# Epoch 2/800
# 614/614 [==============================] - 0s 144us/sample - loss: 31.9351 - y1_output_loss: 12.1326 - y2_output_loss: 19.6940 - y1_output_root_mean_squared_error: 3.4872 - y2_output_root_mean_squared_error: 4.4469 - val_loss: 32.1375 - val_y1_output_loss: 12.4300 - val_y2_output_loss: 18.8895 - val_y1_output_root_mean_squared_error: 3.5676 - val_y2_output_root_mean_squared_error: 4.4056
# Epoch 3/800
# 614/614 [==============================] - 0s 139us/sample - loss: 23.8734 - y1_output_loss: 9.5505 - y2_output_loss: 14.2258 - y1_output_root_mean_squared_error: 3.0972 - y2_output_root_mean_squared_error: 3.7790 - val_loss: 23.8254 - val_y1_output_loss: 10.7670 - val_y2_output_loss: 12.4107 - val_y1_output_root_mean_squared_error: 3.3273 - val_y2_output_root_mean_squared_error: 3.5714
# Epoch 4/800
# 614/614 [==============================] - 0s 138us/sample - loss: 27.2075 - y1_output_loss: 9.3475 - y2_output_loss: 17.6571 - y1_output_root_mean_squared_error: 3.0688 - y2_output_root_mean_squared_error: 4.2178 - val_loss: 23.1157 - val_y1_output_loss: 10.0792 - val_y2_output_loss: 12.3528 - val_y1_output_root_mean_squared_error: 3.2283 - val_y2_output_root_mean_squared_error: 3.5629
# Epoch 5/800
# 614/614 [==============================] - 0s 143us/sample - loss: 25.5374 - y1_output_loss: 9.6498 - y2_output_loss: 15.7807 - y1_output_root_mean_squared_error: 3.1133 - y2_output_root_mean_squared_error: 3.9805 - val_loss: 27.0335 - val_y1_output_loss: 11.2087 - val_y2_output_loss: 15.0329 - val_y1_output_root_mean_squared_error: 3.3913 - val_y2_output_root_mean_squared_error: 3.9411
# Epoch 6/800
# 614/614 [==============================] - 0s 149us/sample - loss: 20.6334 - y1_output_loss: 8.1024 - y2_output_loss: 12.4247 - y1_output_root_mean_squared_error: 2.8473 - y2_output_root_mean_squared_error: 3.5393 - val_loss: 22.0861 - val_y1_output_loss: 8.5348 - val_y2_output_loss: 12.9734 - val_y1_output_root_mean_squared_error: 2.9555 - val_y2_output_root_mean_squared_error: 3.6539
# Epoch 7/800
# 614/614 [==============================] - 0s 144us/sample - loss: 22.5041 - y1_output_loss: 8.8946 - y2_output_loss: 13.6105 - y1_output_root_mean_squared_error: 2.9785 - y2_output_root_mean_squared_error: 3.6923 - val_loss: 23.9726 - val_y1_output_loss: 10.4413 - val_y2_output_loss: 13.0159 - val_y1_output_root_mean_squared_error: 3.2609 - val_y2_output_root_mean_squared_error: 3.6523
# Epoch 8/800
# 614/614 [==============================] - 0s 137us/sample - loss: 22.9056 - y1_output_loss: 8.5109 - y2_output_loss: 14.7405 - y1_output_root_mean_squared_error: 2.9144 - y2_output_root_mean_squared_error: 3.7963 - val_loss: 100.6290 - val_y1_output_loss: 23.0643 - val_y2_output_loss: 78.3545 - val_y1_output_root_mean_squared_error: 4.7484 - val_y2_output_root_mean_squared_error: 8.8364
# Epoch 9/800
# 614/614 [==============================] - 0s 139us/sample - loss: 20.8273 - y1_output_loss: 7.9230 - y2_output_loss: 12.7682 - y1_output_root_mean_squared_error: 2.8231 - y2_output_root_mean_squared_error: 3.5857 - val_loss: 40.5194 - val_y1_output_loss: 10.9562 - val_y2_output_loss: 29.6230 - val_y1_output_root_mean_squared_error: 3.3467 - val_y2_output_root_mean_squared_error: 5.4147
# Epoch 10/800
# 614/614 [==============================] - 0s 143us/sample - loss: 19.5518 - y1_output_loss: 7.5490 - y2_output_loss: 11.8228 - y1_output_root_mean_squared_error: 2.7602 - y2_output_root_mean_squared_error: 3.4544 - val_loss: 19.0435 - val_y1_output_loss: 7.8220 - val_y2_output_loss: 10.7042 - val_y1_output_root_mean_squared_error: 2.8267 - val_y2_output_root_mean_squared_error: 3.3246
# Epoch 11/800
# 614/614 [==============================] - 0s 140us/sample - loss: 18.2152 - y1_output_loss: 7.2020 - y2_output_loss: 11.1598 - y1_output_root_mean_squared_error: 2.6788 - y2_output_root_mean_squared_error: 3.3226 - val_loss: 34.8539 - val_y1_output_loss: 10.5520 - val_y2_output_loss: 24.5728 - val_y1_output_root_mean_squared_error: 3.2764 - val_y2_output_root_mean_squared_error: 4.9111
# Epoch 12/800
# 614/614 [==============================] - 0s 146us/sample - loss: 22.1980 - y1_output_loss: 8.1935 - y2_output_loss: 13.8824 - y1_output_root_mean_squared_error: 2.8725 - y2_output_root_mean_squared_error: 3.7345 - val_loss: 23.6478 - val_y1_output_loss: 8.3989 - val_y2_output_loss: 14.8506 - val_y1_output_root_mean_squared_error: 2.9528 - val_y2_output_root_mean_squared_error: 3.8638
# Epoch 13/800
# 614/614 [==============================] - 0s 151us/sample - loss: 18.8744 - y1_output_loss: 7.2370 - y2_output_loss: 11.5624 - y1_output_root_mean_squared_error: 2.6931 - y2_output_root_mean_squared_error: 3.4091 - val_loss: 20.6113 - val_y1_output_loss: 7.4788 - val_y2_output_loss: 12.8436 - val_y1_output_root_mean_squared_error: 2.7780 - val_y2_output_root_mean_squared_error: 3.5908
# Epoch 14/800
# 614/614 [==============================] - 0s 140us/sample - loss: 15.7993 - y1_output_loss: 6.4039 - y2_output_loss: 9.3016 - y1_output_root_mean_squared_error: 2.5365 - y2_output_root_mean_squared_error: 3.0603 - val_loss: 19.2751 - val_y1_output_loss: 7.3973 - val_y2_output_loss: 11.5550 - val_y1_output_root_mean_squared_error: 2.7649 - val_y2_output_root_mean_squared_error: 3.4103
# Epoch 15/800
# 614/614 [==============================] - 0s 134us/sample - loss: 17.7086 - y1_output_loss: 6.3568 - y2_output_loss: 11.2818 - y1_output_root_mean_squared_error: 2.5288 - y2_output_root_mean_squared_error: 3.3636 - val_loss: 16.1222 - val_y1_output_loss: 6.4448 - val_y2_output_loss: 9.2640 - val_y1_output_root_mean_squared_error: 2.5576 - val_y2_output_root_mean_squared_error: 3.0953
# Epoch 16/800
# 614/614 [==============================] - 0s 137us/sample - loss: 16.2331 - y1_output_loss: 6.0998 - y2_output_loss: 10.0641 - y1_output_root_mean_squared_error: 2.4802 - y2_output_root_mean_squared_error: 3.1751 - val_loss: 18.9763 - val_y1_output_loss: 6.4786 - val_y2_output_loss: 12.1532 - val_y1_output_root_mean_squared_error: 2.5905 - val_y2_output_root_mean_squared_error: 3.5023
# Epoch 17/800
# 614/614 [==============================] - 0s 134us/sample - loss: 16.3244 - y1_output_loss: 6.4297 - y2_output_loss: 9.8825 - y1_output_root_mean_squared_error: 2.5290 - y2_output_root_mean_squared_error: 3.1510 - val_loss: 14.8100 - val_y1_output_loss: 5.6356 - val_y2_output_loss: 8.7365 - val_y1_output_root_mean_squared_error: 2.4002 - val_y2_output_root_mean_squared_error: 3.0082
# Epoch 18/800
# 614/614 [==============================] - 0s 140us/sample - loss: 13.3164 - y1_output_loss: 5.4277 - y2_output_loss: 7.8587 - y1_output_root_mean_squared_error: 2.3357 - y2_output_root_mean_squared_error: 2.8038 - val_loss: 31.2830 - val_y1_output_loss: 8.3112 - val_y2_output_loss: 22.8175 - val_y1_output_root_mean_squared_error: 2.9205 - val_y2_output_root_mean_squared_error: 4.7701
# Epoch 19/800
# 614/614 [==============================] - 0s 143us/sample - loss: 15.9553 - y1_output_loss: 5.8266 - y2_output_loss: 10.0816 - y1_output_root_mean_squared_error: 2.4205 - y2_output_root_mean_squared_error: 3.1775 - val_loss: 17.3103 - val_y1_output_loss: 6.5109 - val_y2_output_loss: 10.4530 - val_y1_output_root_mean_squared_error: 2.5798 - val_y2_output_root_mean_squared_error: 3.2642
# Epoch 20/800
# 614/614 [==============================] - 0s 141us/sample - loss: 15.4122 - y1_output_loss: 5.6587 - y2_output_loss: 9.7532 - y1_output_root_mean_squared_error: 2.3767 - y2_output_root_mean_squared_error: 3.1247 - val_loss: 13.3891 - val_y1_output_loss: 6.0232 - val_y2_output_loss: 7.1475 - val_y1_output_root_mean_squared_error: 2.4554 - val_y2_output_root_mean_squared_error: 2.7130
# Epoch 21/800
# 614/614 [==============================] - 0s 139us/sample - loss: 15.5837 - y1_output_loss: 5.5547 - y2_output_loss: 10.0597 - y1_output_root_mean_squared_error: 2.3309 - y2_output_root_mean_squared_error: 3.1860 - val_loss: 12.4020 - val_y1_output_loss: 5.2885 - val_y2_output_loss: 6.8077 - val_y1_output_root_mean_squared_error: 2.3130 - val_y2_output_root_mean_squared_error: 2.6555
# Epoch 22/800
# 614/614 [==============================] - 0s 140us/sample - loss: 12.8557 - y1_output_loss: 4.5836 - y2_output_loss: 8.2387 - y1_output_root_mean_squared_error: 2.1339 - y2_output_root_mean_squared_error: 2.8813 - val_loss: 19.4204 - val_y1_output_loss: 8.2549 - val_y2_output_loss: 11.1384 - val_y1_output_root_mean_squared_error: 2.8435 - val_y2_output_root_mean_squared_error: 3.3667
# Epoch 23/800
# 614/614 [==============================] - 0s 144us/sample - loss: 11.5723 - y1_output_loss: 4.3824 - y2_output_loss: 7.2724 - y1_output_root_mean_squared_error: 2.0838 - y2_output_root_mean_squared_error: 2.6889 - val_loss: 24.3224 - val_y1_output_loss: 7.4070 - val_y2_output_loss: 16.7729 - val_y1_output_root_mean_squared_error: 2.6992 - val_y2_output_root_mean_squared_error: 4.1275
# Epoch 24/800
# 614/614 [==============================] - 0s 142us/sample - loss: 12.9537 - y1_output_loss: 4.5241 - y2_output_loss: 8.5102 - y1_output_root_mean_squared_error: 2.1220 - y2_output_root_mean_squared_error: 2.9071 - val_loss: 11.2015 - val_y1_output_loss: 4.5059 - val_y2_output_loss: 6.5075 - val_y1_output_root_mean_squared_error: 2.1258 - val_y2_output_root_mean_squared_error: 2.5851
# Epoch 25/800
# 614/614 [==============================] - 0s 153us/sample - loss: 9.7563 - y1_output_loss: 3.9114 - y2_output_loss: 5.8205 - y1_output_root_mean_squared_error: 1.9796 - y2_output_root_mean_squared_error: 2.4161 - val_loss: 14.0234 - val_y1_output_loss: 5.3142 - val_y2_output_loss: 8.5852 - val_y1_output_root_mean_squared_error: 2.2879 - val_y2_output_root_mean_squared_error: 2.9646
# Epoch 26/800
# 614/614 [==============================] - 0s 143us/sample - loss: 10.8076 - y1_output_loss: 3.9774 - y2_output_loss: 6.9165 - y1_output_root_mean_squared_error: 1.9918 - y2_output_root_mean_squared_error: 2.6154 - val_loss: 19.7986 - val_y1_output_loss: 6.6049 - val_y2_output_loss: 13.1674 - val_y1_output_root_mean_squared_error: 2.5865 - val_y2_output_root_mean_squared_error: 3.6206
# Epoch 27/800
# 614/614 [==============================] - 0s 144us/sample - loss: 10.6570 - y1_output_loss: 3.7339 - y2_output_loss: 7.0802 - y1_output_root_mean_squared_error: 1.9235 - y2_output_root_mean_squared_error: 2.6376 - val_loss: 19.9568 - val_y1_output_loss: 5.5607 - val_y2_output_loss: 14.1896 - val_y1_output_root_mean_squared_error: 2.3567 - val_y2_output_root_mean_squared_error: 3.7951
# Epoch 28/800
# 614/614 [==============================] - 0s 142us/sample - loss: 11.8390 - y1_output_loss: 4.0840 - y2_output_loss: 7.7743 - y1_output_root_mean_squared_error: 2.0102 - y2_output_root_mean_squared_error: 2.7925 - val_loss: 22.3361 - val_y1_output_loss: 6.4769 - val_y2_output_loss: 15.7327 - val_y1_output_root_mean_squared_error: 2.5269 - val_y2_output_root_mean_squared_error: 3.9939
# Epoch 29/800
# 614/614 [==============================] - 0s 146us/sample - loss: 11.6339 - y1_output_loss: 4.0048 - y2_output_loss: 7.5762 - y1_output_root_mean_squared_error: 2.0092 - y2_output_root_mean_squared_error: 2.7563 - val_loss: 11.6246 - val_y1_output_loss: 3.8394 - val_y2_output_loss: 7.6524 - val_y1_output_root_mean_squared_error: 1.9583 - val_y2_output_root_mean_squared_error: 2.7910
# Epoch 30/800
# 614/614 [==============================] - 0s 147us/sample - loss: 9.7356 - y1_output_loss: 3.3375 - y2_output_loss: 6.3133 - y1_output_root_mean_squared_error: 1.8343 - y2_output_root_mean_squared_error: 2.5240 - val_loss: 9.3059 - val_y1_output_loss: 3.6051 - val_y2_output_loss: 5.4645 - val_y1_output_root_mean_squared_error: 1.9218 - val_y2_output_root_mean_squared_error: 2.3691
# Epoch 31/800
# 614/614 [==============================] - 0s 151us/sample - loss: 10.6804 - y1_output_loss: 3.4801 - y2_output_loss: 7.1884 - y1_output_root_mean_squared_error: 1.8623 - y2_output_root_mean_squared_error: 2.6856 - val_loss: 11.1820 - val_y1_output_loss: 4.5231 - val_y2_output_loss: 6.9464 - val_y1_output_root_mean_squared_error: 2.0955 - val_y2_output_root_mean_squared_error: 2.6059
# Epoch 32/800
# 614/614 [==============================] - 0s 147us/sample - loss: 9.6003 - y1_output_loss: 3.2948 - y2_output_loss: 6.2285 - y1_output_root_mean_squared_error: 1.8221 - y2_output_root_mean_squared_error: 2.5060 - val_loss: 11.6808 - val_y1_output_loss: 4.4098 - val_y2_output_loss: 6.9823 - val_y1_output_root_mean_squared_error: 2.1331 - val_y2_output_root_mean_squared_error: 2.6704
# Epoch 33/800
# 614/614 [==============================] - 0s 142us/sample - loss: 8.6115 - y1_output_loss: 2.8609 - y2_output_loss: 5.7167 - y1_output_root_mean_squared_error: 1.6962 - y2_output_root_mean_squared_error: 2.3947 - val_loss: 9.3129 - val_y1_output_loss: 3.1392 - val_y2_output_loss: 5.9389 - val_y1_output_root_mean_squared_error: 1.7886 - val_y2_output_root_mean_squared_error: 2.4726
# Epoch 34/800
# 614/614 [==============================] - 0s 145us/sample - loss: 8.9110 - y1_output_loss: 2.9578 - y2_output_loss: 5.9128 - y1_output_root_mean_squared_error: 1.7157 - y2_output_root_mean_squared_error: 2.4428 - val_loss: 11.3716 - val_y1_output_loss: 5.2214 - val_y2_output_loss: 6.1814 - val_y1_output_root_mean_squared_error: 2.2400 - val_y2_output_root_mean_squared_error: 2.5207
# Epoch 35/800
# 614/614 [==============================] - 0s 136us/sample - loss: 9.0213 - y1_output_loss: 2.9505 - y2_output_loss: 5.9946 - y1_output_root_mean_squared_error: 1.7248 - y2_output_root_mean_squared_error: 2.4589 - val_loss: 8.4291 - val_y1_output_loss: 3.0843 - val_y2_output_loss: 5.1925 - val_y1_output_root_mean_squared_error: 1.7601 - val_y2_output_root_mean_squared_error: 2.3090
# Epoch 36/800
# 614/614 [==============================] - 0s 138us/sample - loss: 7.9054 - y1_output_loss: 2.5690 - y2_output_loss: 5.2950 - y1_output_root_mean_squared_error: 1.6071 - y2_output_root_mean_squared_error: 2.3071 - val_loss: 9.9505 - val_y1_output_loss: 3.6056 - val_y2_output_loss: 6.2941 - val_y1_output_root_mean_squared_error: 1.8728 - val_y2_output_root_mean_squared_error: 2.5383
# Epoch 37/800
# 614/614 [==============================] - 0s 148us/sample - loss: 9.5562 - y1_output_loss: 2.8911 - y2_output_loss: 6.5735 - y1_output_root_mean_squared_error: 1.7086 - y2_output_root_mean_squared_error: 2.5762 - val_loss: 9.3050 - val_y1_output_loss: 3.6984 - val_y2_output_loss: 5.4523 - val_y1_output_root_mean_squared_error: 1.9118 - val_y2_output_root_mean_squared_error: 2.3770
# Epoch 38/800
# 614/614 [==============================] - 0s 146us/sample - loss: 7.2732 - y1_output_loss: 2.4673 - y2_output_loss: 4.7766 - y1_output_root_mean_squared_error: 1.5763 - y2_output_root_mean_squared_error: 2.1882 - val_loss: 9.9898 - val_y1_output_loss: 2.9396 - val_y2_output_loss: 6.8649 - val_y1_output_root_mean_squared_error: 1.7292 - val_y2_output_root_mean_squared_error: 2.6457
# Epoch 39/800
# 614/614 [==============================] - 0s 144us/sample - loss: 9.9064 - y1_output_loss: 3.4530 - y2_output_loss: 6.4354 - y1_output_root_mean_squared_error: 1.8609 - y2_output_root_mean_squared_error: 2.5384 - val_loss: 18.5465 - val_y1_output_loss: 5.3002 - val_y2_output_loss: 13.0594 - val_y1_output_root_mean_squared_error: 2.3367 - val_y2_output_root_mean_squared_error: 3.6175
# Epoch 40/800
# 614/614 [==============================] - 0s 144us/sample - loss: 7.9854 - y1_output_loss: 2.5642 - y2_output_loss: 5.4378 - y1_output_root_mean_squared_error: 1.6014 - y2_output_root_mean_squared_error: 2.3283 - val_loss: 6.9133 - val_y1_output_loss: 2.4875 - val_y2_output_loss: 4.3513 - val_y1_output_root_mean_squared_error: 1.5548 - val_y2_output_root_mean_squared_error: 2.1203
# Epoch 41/800
# 614/614 [==============================] - 0s 141us/sample - loss: 8.2262 - y1_output_loss: 2.4962 - y2_output_loss: 5.7848 - y1_output_root_mean_squared_error: 1.5832 - y2_output_root_mean_squared_error: 2.3916 - val_loss: 23.9019 - val_y1_output_loss: 3.6324 - val_y2_output_loss: 20.2417 - val_y1_output_root_mean_squared_error: 1.8906 - val_y2_output_root_mean_squared_error: 4.5086
# Epoch 42/800
# 614/614 [==============================] - 0s 137us/sample - loss: 7.3526 - y1_output_loss: 2.4132 - y2_output_loss: 4.8713 - y1_output_root_mean_squared_error: 1.5601 - y2_output_root_mean_squared_error: 2.2178 - val_loss: 7.6356 - val_y1_output_loss: 2.3204 - val_y2_output_loss: 5.1452 - val_y1_output_root_mean_squared_error: 1.5255 - val_y2_output_root_mean_squared_error: 2.3040
# Epoch 43/800
# 614/614 [==============================] - 0s 150us/sample - loss: 8.0397 - y1_output_loss: 2.5450 - y2_output_loss: 5.4502 - y1_output_root_mean_squared_error: 1.5937 - y2_output_root_mean_squared_error: 2.3452 - val_loss: 7.5058 - val_y1_output_loss: 2.5483 - val_y2_output_loss: 4.7720 - val_y1_output_root_mean_squared_error: 1.6014 - val_y2_output_root_mean_squared_error: 2.2229
# Epoch 44/800
# 614/614 [==============================] - 0s 156us/sample - loss: 7.4116 - y1_output_loss: 2.5364 - y2_output_loss: 4.8525 - y1_output_root_mean_squared_error: 1.5995 - y2_output_root_mean_squared_error: 2.2030 - val_loss: 7.6463 - val_y1_output_loss: 3.0981 - val_y2_output_loss: 4.5876 - val_y1_output_root_mean_squared_error: 1.7259 - val_y2_output_root_mean_squared_error: 2.1605
# Epoch 45/800
# 614/614 [==============================] - 0s 153us/sample - loss: 6.9457 - y1_output_loss: 2.2385 - y2_output_loss: 4.6614 - y1_output_root_mean_squared_error: 1.5014 - y2_output_root_mean_squared_error: 2.1660 - val_loss: 6.6371 - val_y1_output_loss: 2.3269 - val_y2_output_loss: 4.1712 - val_y1_output_root_mean_squared_error: 1.5237 - val_y2_output_root_mean_squared_error: 2.0774
# Epoch 46/800
# 614/614 [==============================] - 0s 147us/sample - loss: 6.3914 - y1_output_loss: 2.1548 - y2_output_loss: 4.1987 - y1_output_root_mean_squared_error: 1.4737 - y2_output_root_mean_squared_error: 2.0542 - val_loss: 7.4688 - val_y1_output_loss: 2.8223 - val_y2_output_loss: 4.4347 - val_y1_output_root_mean_squared_error: 1.7023 - val_y2_output_root_mean_squared_error: 2.1380
# Epoch 47/800
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1884 - y1_output_loss: 1.9111 - y2_output_loss: 4.2648 - y1_output_root_mean_squared_error: 1.3872 - y2_output_root_mean_squared_error: 2.0650 - val_loss: 11.3062 - val_y1_output_loss: 3.0796 - val_y2_output_loss: 8.2005 - val_y1_output_root_mean_squared_error: 1.7230 - val_y2_output_root_mean_squared_error: 2.8874
# Epoch 48/800
# 614/614 [==============================] - 0s 149us/sample - loss: 6.3874 - y1_output_loss: 2.0703 - y2_output_loss: 4.2892 - y1_output_root_mean_squared_error: 1.4447 - y2_output_root_mean_squared_error: 2.0737 - val_loss: 7.0171 - val_y1_output_loss: 2.6670 - val_y2_output_loss: 4.3724 - val_y1_output_root_mean_squared_error: 1.5996 - val_y2_output_root_mean_squared_error: 2.1115
# Epoch 49/800
# 614/614 [==============================] - 0s 155us/sample - loss: 7.5694 - y1_output_loss: 2.3113 - y2_output_loss: 5.2559 - y1_output_root_mean_squared_error: 1.5253 - y2_output_root_mean_squared_error: 2.2898 - val_loss: 9.7760 - val_y1_output_loss: 2.6705 - val_y2_output_loss: 6.9493 - val_y1_output_root_mean_squared_error: 1.6525 - val_y2_output_root_mean_squared_error: 2.6543
# Epoch 50/800
# 614/614 [==============================] - 0s 147us/sample - loss: 5.9614 - y1_output_loss: 1.9525 - y2_output_loss: 3.9771 - y1_output_root_mean_squared_error: 1.4003 - y2_output_root_mean_squared_error: 2.0001 - val_loss: 9.9742 - val_y1_output_loss: 3.6382 - val_y2_output_loss: 6.4470 - val_y1_output_root_mean_squared_error: 1.8503 - val_y2_output_root_mean_squared_error: 2.5594
# Epoch 51/800
# 614/614 [==============================] - 0s 146us/sample - loss: 9.4576 - y1_output_loss: 2.9188 - y2_output_loss: 6.5362 - y1_output_root_mean_squared_error: 1.7099 - y2_output_root_mean_squared_error: 2.5561 - val_loss: 9.2421 - val_y1_output_loss: 3.6967 - val_y2_output_loss: 5.6828 - val_y1_output_root_mean_squared_error: 1.8807 - val_y2_output_root_mean_squared_error: 2.3885
# Epoch 52/800
# 614/614 [==============================] - 0s 141us/sample - loss: 7.4418 - y1_output_loss: 2.3616 - y2_output_loss: 5.0599 - y1_output_root_mean_squared_error: 1.5418 - y2_output_root_mean_squared_error: 2.2505 - val_loss: 7.0777 - val_y1_output_loss: 2.1851 - val_y2_output_loss: 4.6986 - val_y1_output_root_mean_squared_error: 1.4919 - val_y2_output_root_mean_squared_error: 2.2027
# Epoch 53/800
# 614/614 [==============================] - 0s 140us/sample - loss: 5.8637 - y1_output_loss: 1.9352 - y2_output_loss: 3.9376 - y1_output_root_mean_squared_error: 1.3833 - y2_output_root_mean_squared_error: 1.9875 - val_loss: 11.2185 - val_y1_output_loss: 3.0475 - val_y2_output_loss: 7.9869 - val_y1_output_root_mean_squared_error: 1.7724 - val_y2_output_root_mean_squared_error: 2.8420
# Epoch 54/800
# 614/614 [==============================] - 0s 139us/sample - loss: 6.2722 - y1_output_loss: 1.9895 - y2_output_loss: 4.3000 - y1_output_root_mean_squared_error: 1.4046 - y2_output_root_mean_squared_error: 2.0735 - val_loss: 16.2667 - val_y1_output_loss: 6.6617 - val_y2_output_loss: 9.8386 - val_y1_output_root_mean_squared_error: 2.5168 - val_y2_output_root_mean_squared_error: 3.1516
# Epoch 55/800
# 614/614 [==============================] - 0s 155us/sample - loss: 6.4498 - y1_output_loss: 2.0523 - y2_output_loss: 4.3516 - y1_output_root_mean_squared_error: 1.4368 - y2_output_root_mean_squared_error: 2.0941 - val_loss: 6.6500 - val_y1_output_loss: 2.2463 - val_y2_output_loss: 4.2956 - val_y1_output_root_mean_squared_error: 1.4853 - val_y2_output_root_mean_squared_error: 2.1080
# Epoch 56/800
# 614/614 [==============================] - 0s 144us/sample - loss: 6.7181 - y1_output_loss: 2.2172 - y2_output_loss: 4.4624 - y1_output_root_mean_squared_error: 1.4937 - y2_output_root_mean_squared_error: 2.1182 - val_loss: 10.7119 - val_y1_output_loss: 3.4114 - val_y2_output_loss: 7.2832 - val_y1_output_root_mean_squared_error: 1.8176 - val_y2_output_root_mean_squared_error: 2.7218
# Epoch 57/800
# 614/614 [==============================] - 0s 144us/sample - loss: 5.0303 - y1_output_loss: 1.7135 - y2_output_loss: 3.3743 - y1_output_root_mean_squared_error: 1.3108 - y2_output_root_mean_squared_error: 1.8199 - val_loss: 28.4381 - val_y1_output_loss: 6.4930 - val_y2_output_loss: 22.3678 - val_y1_output_root_mean_squared_error: 2.5389 - val_y2_output_root_mean_squared_error: 4.6896
# Epoch 58/800
# 614/614 [==============================] - 0s 145us/sample - loss: 5.6617 - y1_output_loss: 1.7975 - y2_output_loss: 3.8749 - y1_output_root_mean_squared_error: 1.3378 - y2_output_root_mean_squared_error: 1.9677 - val_loss: 15.9573 - val_y1_output_loss: 5.5033 - val_y2_output_loss: 10.8777 - val_y1_output_root_mean_squared_error: 2.2811 - val_y2_output_root_mean_squared_error: 3.2793
# Epoch 59/800
# 614/614 [==============================] - 0s 148us/sample - loss: 5.6443 - y1_output_loss: 1.6783 - y2_output_loss: 4.0250 - y1_output_root_mean_squared_error: 1.3001 - y2_output_root_mean_squared_error: 1.9885 - val_loss: 23.1502 - val_y1_output_loss: 4.8049 - val_y2_output_loss: 18.8753 - val_y1_output_root_mean_squared_error: 2.1218 - val_y2_output_root_mean_squared_error: 4.3183
# Epoch 60/800
# 614/614 [==============================] - 0s 142us/sample - loss: 6.5298 - y1_output_loss: 1.9159 - y2_output_loss: 4.5816 - y1_output_root_mean_squared_error: 1.3815 - y2_output_root_mean_squared_error: 2.1497 - val_loss: 7.0564 - val_y1_output_loss: 2.2165 - val_y2_output_loss: 4.6988 - val_y1_output_root_mean_squared_error: 1.5024 - val_y2_output_root_mean_squared_error: 2.1907
# Epoch 61/800
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1919 - y1_output_loss: 1.8778 - y2_output_loss: 4.3314 - y1_output_root_mean_squared_error: 1.3729 - y2_output_root_mean_squared_error: 2.0753 - val_loss: 13.6236 - val_y1_output_loss: 4.6461 - val_y2_output_loss: 8.8369 - val_y1_output_root_mean_squared_error: 2.1518 - val_y2_output_root_mean_squared_error: 2.9989
# Epoch 62/800
# 614/614 [==============================] - 0s 138us/sample - loss: 4.7513 - y1_output_loss: 1.6471 - y2_output_loss: 3.2774 - y1_output_root_mean_squared_error: 1.2552 - y2_output_root_mean_squared_error: 1.7821 - val_loss: 33.5309 - val_y1_output_loss: 13.2797 - val_y2_output_loss: 20.7300 - val_y1_output_root_mean_squared_error: 3.5740 - val_y2_output_root_mean_squared_error: 4.5561
# Epoch 63/800
# 614/614 [==============================] - 0s 141us/sample - loss: 5.7135 - y1_output_loss: 1.7957 - y2_output_loss: 3.9448 - y1_output_root_mean_squared_error: 1.3441 - y2_output_root_mean_squared_error: 1.9766 - val_loss: 17.0999 - val_y1_output_loss: 3.5224 - val_y2_output_loss: 13.5654 - val_y1_output_root_mean_squared_error: 1.8816 - val_y2_output_root_mean_squared_error: 3.6823
# Epoch 64/800
# 614/614 [==============================] - 0s 135us/sample - loss: 5.9041 - y1_output_loss: 1.8441 - y2_output_loss: 4.0351 - y1_output_root_mean_squared_error: 1.3596 - y2_output_root_mean_squared_error: 2.0138 - val_loss: 6.4603 - val_y1_output_loss: 1.8441 - val_y2_output_loss: 4.5120 - val_y1_output_root_mean_squared_error: 1.3392 - val_y2_output_root_mean_squared_error: 2.1603
# Epoch 65/800
# 614/614 [==============================] - 0s 146us/sample - loss: 5.0778 - y1_output_loss: 1.4433 - y2_output_loss: 3.6305 - y1_output_root_mean_squared_error: 1.2021 - y2_output_root_mean_squared_error: 1.9060 - val_loss: 6.5970 - val_y1_output_loss: 1.7259 - val_y2_output_loss: 4.8200 - val_y1_output_root_mean_squared_error: 1.3166 - val_y2_output_root_mean_squared_error: 2.2053
# Epoch 66/800
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3578 - y1_output_loss: 1.6297 - y2_output_loss: 3.6991 - y1_output_root_mean_squared_error: 1.2769 - y2_output_root_mean_squared_error: 1.9306 - val_loss: 8.4611 - val_y1_output_loss: 3.9409 - val_y2_output_loss: 4.6162 - val_y1_output_root_mean_squared_error: 1.9292 - val_y2_output_root_mean_squared_error: 2.1770
# Epoch 67/800
# 614/614 [==============================] - 0s 143us/sample - loss: 5.4811 - y1_output_loss: 1.4972 - y2_output_loss: 3.9412 - y1_output_root_mean_squared_error: 1.2279 - y2_output_root_mean_squared_error: 1.9933 - val_loss: 5.5746 - val_y1_output_loss: 1.8494 - val_y2_output_loss: 3.6202 - val_y1_output_root_mean_squared_error: 1.3678 - val_y2_output_root_mean_squared_error: 1.9245
# Epoch 68/800
# 614/614 [==============================] - 0s 145us/sample - loss: 4.2128 - y1_output_loss: 1.1986 - y2_output_loss: 2.9863 - y1_output_root_mean_squared_error: 1.0955 - y2_output_root_mean_squared_error: 1.7357 - val_loss: 6.4124 - val_y1_output_loss: 1.6218 - val_y2_output_loss: 4.7253 - val_y1_output_root_mean_squared_error: 1.2534 - val_y2_output_root_mean_squared_error: 2.2003
# Epoch 69/800
# 614/614 [==============================] - 0s 142us/sample - loss: 6.9058 - y1_output_loss: 2.0902 - y2_output_loss: 4.8488 - y1_output_root_mean_squared_error: 1.4391 - y2_output_root_mean_squared_error: 2.1988 - val_loss: 10.0641 - val_y1_output_loss: 3.7051 - val_y2_output_loss: 6.8038 - val_y1_output_root_mean_squared_error: 1.8452 - val_y2_output_root_mean_squared_error: 2.5806
# Epoch 70/800
# 614/614 [==============================] - 0s 148us/sample - loss: 5.0969 - y1_output_loss: 1.3593 - y2_output_loss: 3.7281 - y1_output_root_mean_squared_error: 1.1675 - y2_output_root_mean_squared_error: 1.9323 - val_loss: 10.7703 - val_y1_output_loss: 2.8209 - val_y2_output_loss: 7.9558 - val_y1_output_root_mean_squared_error: 1.6976 - val_y2_output_root_mean_squared_error: 2.8086
# Epoch 71/800
# 614/614 [==============================] - 0s 157us/sample - loss: 4.4918 - y1_output_loss: 1.2712 - y2_output_loss: 3.3283 - y1_output_root_mean_squared_error: 1.1064 - y2_output_root_mean_squared_error: 1.8077 - val_loss: 26.5868 - val_y1_output_loss: 7.5546 - val_y2_output_loss: 19.2780 - val_y1_output_root_mean_squared_error: 2.7547 - val_y2_output_root_mean_squared_error: 4.3587
# Epoch 72/800
# 614/614 [==============================] - 0s 138us/sample - loss: 8.4199 - y1_output_loss: 2.5764 - y2_output_loss: 5.7936 - y1_output_root_mean_squared_error: 1.6050 - y2_output_root_mean_squared_error: 2.4174 - val_loss: 6.7460 - val_y1_output_loss: 2.5651 - val_y2_output_loss: 4.3035 - val_y1_output_root_mean_squared_error: 1.5773 - val_y2_output_root_mean_squared_error: 2.0635
# Epoch 73/800
# 614/614 [==============================] - 0s 156us/sample - loss: 4.9854 - y1_output_loss: 1.2646 - y2_output_loss: 4.0089 - y1_output_root_mean_squared_error: 1.1057 - y2_output_root_mean_squared_error: 1.9398 - val_loss: 75.1714 - val_y1_output_loss: 21.0564 - val_y2_output_loss: 56.0910 - val_y1_output_root_mean_squared_error: 4.4644 - val_y2_output_root_mean_squared_error: 7.4324
# Epoch 74/800
# 614/614 [==============================] - 0s 145us/sample - loss: 6.0507 - y1_output_loss: 1.8220 - y2_output_loss: 4.2270 - y1_output_root_mean_squared_error: 1.3520 - y2_output_root_mean_squared_error: 2.0550 - val_loss: 9.5801 - val_y1_output_loss: 1.9545 - val_y2_output_loss: 7.6019 - val_y1_output_root_mean_squared_error: 1.3746 - val_y2_output_root_mean_squared_error: 2.7732
# Epoch 75/800
# 614/614 [==============================] - 0s 149us/sample - loss: 4.0380 - y1_output_loss: 1.1010 - y2_output_loss: 2.9744 - y1_output_root_mean_squared_error: 1.0492 - y2_output_root_mean_squared_error: 1.7138 - val_loss: 10.8223 - val_y1_output_loss: 2.3639 - val_y2_output_loss: 8.3625 - val_y1_output_root_mean_squared_error: 1.5124 - val_y2_output_root_mean_squared_error: 2.9215
# Epoch 76/800
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7369 - y1_output_loss: 1.0570 - y2_output_loss: 2.6875 - y1_output_root_mean_squared_error: 1.0308 - y2_output_root_mean_squared_error: 1.6353 - val_loss: 5.7812 - val_y1_output_loss: 1.6094 - val_y2_output_loss: 4.0867 - val_y1_output_root_mean_squared_error: 1.2682 - val_y2_output_root_mean_squared_error: 2.0428
# Epoch 77/800
# 614/614 [==============================] - 0s 146us/sample - loss: 5.3222 - y1_output_loss: 1.3334 - y2_output_loss: 3.9602 - y1_output_root_mean_squared_error: 1.1596 - y2_output_root_mean_squared_error: 1.9944 - val_loss: 4.1308 - val_y1_output_loss: 1.2092 - val_y2_output_loss: 2.8795 - val_y1_output_root_mean_squared_error: 1.0961 - val_y2_output_root_mean_squared_error: 1.7115
# Epoch 78/800
# 614/614 [==============================] - 0s 143us/sample - loss: 4.0290 - y1_output_loss: 1.0821 - y2_output_loss: 2.9933 - y1_output_root_mean_squared_error: 1.0398 - y2_output_root_mean_squared_error: 1.7169 - val_loss: 13.2018 - val_y1_output_loss: 2.6726 - val_y2_output_loss: 10.4771 - val_y1_output_root_mean_squared_error: 1.6144 - val_y2_output_root_mean_squared_error: 3.2551
# Epoch 79/800
# 614/614 [==============================] - 0s 164us/sample - loss: 3.6942 - y1_output_loss: 0.9449 - y2_output_loss: 2.7251 - y1_output_root_mean_squared_error: 0.9768 - y2_output_root_mean_squared_error: 1.6553 - val_loss: 5.1378 - val_y1_output_loss: 1.7273 - val_y2_output_loss: 3.4195 - val_y1_output_root_mean_squared_error: 1.2925 - val_y2_output_root_mean_squared_error: 1.8620
# Epoch 80/800
# 614/614 [==============================] - 0s 151us/sample - loss: 3.2200 - y1_output_loss: 0.8888 - y2_output_loss: 2.3379 - y1_output_root_mean_squared_error: 0.9367 - y2_output_root_mean_squared_error: 1.5306 - val_loss: 6.4029 - val_y1_output_loss: 2.0479 - val_y2_output_loss: 4.3222 - val_y1_output_root_mean_squared_error: 1.3951 - val_y2_output_root_mean_squared_error: 2.1111
# Epoch 81/800
# 614/614 [==============================] - 0s 149us/sample - loss: 3.6397 - y1_output_loss: 0.9854 - y2_output_loss: 2.6623 - y1_output_root_mean_squared_error: 0.9820 - y2_output_root_mean_squared_error: 1.6357 - val_loss: 7.2100 - val_y1_output_loss: 2.8125 - val_y2_output_loss: 4.3586 - val_y1_output_root_mean_squared_error: 1.6943 - val_y2_output_root_mean_squared_error: 2.0831
# Epoch 82/800
# 614/614 [==============================] - 0s 144us/sample - loss: 4.0491 - y1_output_loss: 1.1054 - y2_output_loss: 2.9146 - y1_output_root_mean_squared_error: 1.0558 - y2_output_root_mean_squared_error: 1.7130 - val_loss: 3.7188 - val_y1_output_loss: 0.9713 - val_y2_output_loss: 2.6933 - val_y1_output_root_mean_squared_error: 0.9953 - val_y2_output_root_mean_squared_error: 1.6517
# Epoch 83/800
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0714 - y1_output_loss: 0.7478 - y2_output_loss: 2.3214 - y1_output_root_mean_squared_error: 0.8669 - y2_output_root_mean_squared_error: 1.5231 - val_loss: 5.1123 - val_y1_output_loss: 1.3144 - val_y2_output_loss: 3.7010 - val_y1_output_root_mean_squared_error: 1.1301 - val_y2_output_root_mean_squared_error: 1.9584
# Epoch 84/800
# 614/614 [==============================] - 0s 135us/sample - loss: 4.1226 - y1_output_loss: 1.0768 - y2_output_loss: 3.0176 - y1_output_root_mean_squared_error: 1.0389 - y2_output_root_mean_squared_error: 1.7445 - val_loss: 3.9348 - val_y1_output_loss: 1.0243 - val_y2_output_loss: 2.8385 - val_y1_output_root_mean_squared_error: 1.0058 - val_y2_output_root_mean_squared_error: 1.7097
# Epoch 85/800
# 614/614 [==============================] - 0s 145us/sample - loss: 4.2166 - y1_output_loss: 1.0752 - y2_output_loss: 3.1158 - y1_output_root_mean_squared_error: 1.0393 - y2_output_root_mean_squared_error: 1.7710 - val_loss: 3.5143 - val_y1_output_loss: 1.0076 - val_y2_output_loss: 2.4488 - val_y1_output_root_mean_squared_error: 1.0045 - val_y2_output_root_mean_squared_error: 1.5828
# Epoch 86/800
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8448 - y1_output_loss: 0.6377 - y2_output_loss: 2.1855 - y1_output_root_mean_squared_error: 0.8011 - y2_output_root_mean_squared_error: 1.4842 - val_loss: 3.2587 - val_y1_output_loss: 0.9287 - val_y2_output_loss: 2.2832 - val_y1_output_root_mean_squared_error: 0.9603 - val_y2_output_root_mean_squared_error: 1.5285
# Epoch 87/800
# 614/614 [==============================] - 0s 140us/sample - loss: 3.8307 - y1_output_loss: 0.9361 - y2_output_loss: 2.8734 - y1_output_root_mean_squared_error: 0.9688 - y2_output_root_mean_squared_error: 1.7006 - val_loss: 3.6031 - val_y1_output_loss: 0.9550 - val_y2_output_loss: 2.6260 - val_y1_output_root_mean_squared_error: 0.9703 - val_y2_output_root_mean_squared_error: 1.6315
# Epoch 88/800
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6205 - y1_output_loss: 0.6049 - y2_output_loss: 2.0355 - y1_output_root_mean_squared_error: 0.7807 - y2_output_root_mean_squared_error: 1.4181 - val_loss: 4.4075 - val_y1_output_loss: 0.9072 - val_y2_output_loss: 3.3804 - val_y1_output_root_mean_squared_error: 0.9491 - val_y2_output_root_mean_squared_error: 1.8726
# Epoch 89/800
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6563 - y1_output_loss: 0.7865 - y2_output_loss: 2.9040 - y1_output_root_mean_squared_error: 0.8884 - y2_output_root_mean_squared_error: 1.6932 - val_loss: 6.7720 - val_y1_output_loss: 1.4397 - val_y2_output_loss: 5.2177 - val_y1_output_root_mean_squared_error: 1.1920 - val_y2_output_root_mean_squared_error: 2.3132
# Epoch 90/800
# 614/614 [==============================] - 0s 143us/sample - loss: 5.3977 - y1_output_loss: 1.2624 - y2_output_loss: 4.0889 - y1_output_root_mean_squared_error: 1.1285 - y2_output_root_mean_squared_error: 2.0308 - val_loss: 3.7384 - val_y1_output_loss: 1.1094 - val_y2_output_loss: 2.5851 - val_y1_output_root_mean_squared_error: 1.0445 - val_y2_output_root_mean_squared_error: 1.6271
# Epoch 91/800
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6343 - y1_output_loss: 0.9491 - y2_output_loss: 2.6859 - y1_output_root_mean_squared_error: 0.9757 - y2_output_root_mean_squared_error: 1.6378 - val_loss: 6.5773 - val_y1_output_loss: 0.9975 - val_y2_output_loss: 5.6127 - val_y1_output_root_mean_squared_error: 1.0128 - val_y2_output_root_mean_squared_error: 2.3562
# Epoch 92/800
# 614/614 [==============================] - 0s 148us/sample - loss: 2.9897 - y1_output_loss: 0.5615 - y2_output_loss: 2.4058 - y1_output_root_mean_squared_error: 0.7526 - y2_output_root_mean_squared_error: 1.5567 - val_loss: 4.1944 - val_y1_output_loss: 1.0837 - val_y2_output_loss: 3.0310 - val_y1_output_root_mean_squared_error: 1.0293 - val_y2_output_root_mean_squared_error: 1.7706
# Epoch 93/800
# 614/614 [==============================] - 0s 149us/sample - loss: 3.3464 - y1_output_loss: 0.8421 - y2_output_loss: 2.5279 - y1_output_root_mean_squared_error: 0.9162 - y2_output_root_mean_squared_error: 1.5834 - val_loss: 4.3953 - val_y1_output_loss: 1.0600 - val_y2_output_loss: 3.3268 - val_y1_output_root_mean_squared_error: 1.0367 - val_y2_output_root_mean_squared_error: 1.8222
# Epoch 94/800
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8996 - y1_output_loss: 0.7511 - y2_output_loss: 2.1578 - y1_output_root_mean_squared_error: 0.8664 - y2_output_root_mean_squared_error: 1.4659 - val_loss: 3.2385 - val_y1_output_loss: 0.8951 - val_y2_output_loss: 2.3343 - val_y1_output_root_mean_squared_error: 0.9361 - val_y2_output_root_mean_squared_error: 1.5370
# Epoch 95/800
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4907 - y1_output_loss: 0.5955 - y2_output_loss: 1.9977 - y1_output_root_mean_squared_error: 0.7418 - y2_output_root_mean_squared_error: 1.3930 - val_loss: 31.6272 - val_y1_output_loss: 11.9132 - val_y2_output_loss: 19.8770 - val_y1_output_root_mean_squared_error: 3.4094 - val_y2_output_root_mean_squared_error: 4.4725
# Epoch 96/800
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8777 - y1_output_loss: 0.7848 - y2_output_loss: 2.0677 - y1_output_root_mean_squared_error: 0.8891 - y2_output_root_mean_squared_error: 1.4447 - val_loss: 3.3205 - val_y1_output_loss: 0.8850 - val_y2_output_loss: 2.3904 - val_y1_output_root_mean_squared_error: 0.9401 - val_y2_output_root_mean_squared_error: 1.5610
# Epoch 97/800
# 614/614 [==============================] - 0s 143us/sample - loss: 2.8645 - y1_output_loss: 0.6324 - y2_output_loss: 2.2355 - y1_output_root_mean_squared_error: 0.7959 - y2_output_root_mean_squared_error: 1.4937 - val_loss: 6.2209 - val_y1_output_loss: 1.1232 - val_y2_output_loss: 4.9760 - val_y1_output_root_mean_squared_error: 1.0449 - val_y2_output_root_mean_squared_error: 2.2647
# Epoch 98/800
# 614/614 [==============================] - 0s 143us/sample - loss: 2.9684 - y1_output_loss: 0.6505 - y2_output_loss: 2.3113 - y1_output_root_mean_squared_error: 0.8046 - y2_output_root_mean_squared_error: 1.5235 - val_loss: 13.6092 - val_y1_output_loss: 5.5487 - val_y2_output_loss: 8.5857 - val_y1_output_root_mean_squared_error: 2.3066 - val_y2_output_root_mean_squared_error: 2.8790
# Epoch 99/800
# 614/614 [==============================] - 0s 139us/sample - loss: 3.5567 - y1_output_loss: 0.9452 - y2_output_loss: 2.6065 - y1_output_root_mean_squared_error: 0.9752 - y2_output_root_mean_squared_error: 1.6142 - val_loss: 4.2964 - val_y1_output_loss: 1.1061 - val_y2_output_loss: 3.1646 - val_y1_output_root_mean_squared_error: 1.0599 - val_y2_output_root_mean_squared_error: 1.7813
# Epoch 100/800
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3862 - y1_output_loss: 0.5981 - y2_output_loss: 1.7967 - y1_output_root_mean_squared_error: 0.7751 - y2_output_root_mean_squared_error: 1.3362 - val_loss: 7.8590 - val_y1_output_loss: 1.3805 - val_y2_output_loss: 6.3788 - val_y1_output_root_mean_squared_error: 1.1660 - val_y2_output_root_mean_squared_error: 2.5494
# Epoch 101/800
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7327 - y1_output_loss: 0.6629 - y2_output_loss: 2.0926 - y1_output_root_mean_squared_error: 0.8163 - y2_output_root_mean_squared_error: 1.4375 - val_loss: 4.4261 - val_y1_output_loss: 0.9518 - val_y2_output_loss: 3.3832 - val_y1_output_root_mean_squared_error: 0.9644 - val_y2_output_root_mean_squared_error: 1.8698
# Epoch 102/800
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5970 - y1_output_loss: 0.5368 - y2_output_loss: 2.0401 - y1_output_root_mean_squared_error: 0.7352 - y2_output_root_mean_squared_error: 1.4340 - val_loss: 2.8897 - val_y1_output_loss: 0.7102 - val_y2_output_loss: 2.1244 - val_y1_output_root_mean_squared_error: 0.8463 - val_y2_output_root_mean_squared_error: 1.4742
# Epoch 103/800
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4471 - y1_output_loss: 0.5783 - y2_output_loss: 1.8690 - y1_output_root_mean_squared_error: 0.7633 - y2_output_root_mean_squared_error: 1.3655 - val_loss: 3.1657 - val_y1_output_loss: 0.6092 - val_y2_output_loss: 2.4798 - val_y1_output_root_mean_squared_error: 0.7860 - val_y2_output_root_mean_squared_error: 1.5962
# Epoch 104/800
# 614/614 [==============================] - 0s 143us/sample - loss: 2.1541 - y1_output_loss: 0.4708 - y2_output_loss: 1.6936 - y1_output_root_mean_squared_error: 0.6842 - y2_output_root_mean_squared_error: 1.2984 - val_loss: 3.3317 - val_y1_output_loss: 0.8648 - val_y2_output_loss: 2.3930 - val_y1_output_root_mean_squared_error: 0.9400 - val_y2_output_root_mean_squared_error: 1.5646
# Epoch 105/800
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9335 - y1_output_loss: 0.6630 - y2_output_loss: 2.2453 - y1_output_root_mean_squared_error: 0.8175 - y2_output_root_mean_squared_error: 1.5051 - val_loss: 3.0883 - val_y1_output_loss: 0.8030 - val_y2_output_loss: 2.2539 - val_y1_output_root_mean_squared_error: 0.8930 - val_y2_output_root_mean_squared_error: 1.5136
# Epoch 106/800
# 614/614 [==============================] - 0s 144us/sample - loss: 4.0339 - y1_output_loss: 1.0294 - y2_output_loss: 2.9974 - y1_output_root_mean_squared_error: 1.0169 - y2_output_root_mean_squared_error: 1.7320 - val_loss: 4.9193 - val_y1_output_loss: 0.8780 - val_y2_output_loss: 3.9699 - val_y1_output_root_mean_squared_error: 0.9318 - val_y2_output_root_mean_squared_error: 2.0127
# Epoch 107/800
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4033 - y1_output_loss: 0.9493 - y2_output_loss: 2.4645 - y1_output_root_mean_squared_error: 0.9778 - y2_output_root_mean_squared_error: 1.5643 - val_loss: 7.7323 - val_y1_output_loss: 1.2731 - val_y2_output_loss: 6.4539 - val_y1_output_root_mean_squared_error: 1.1410 - val_y2_output_root_mean_squared_error: 2.5358
# Epoch 108/800
# 614/614 [==============================] - 0s 139us/sample - loss: 3.9290 - y1_output_loss: 1.1351 - y2_output_loss: 2.7853 - y1_output_root_mean_squared_error: 1.0699 - y2_output_root_mean_squared_error: 1.6686 - val_loss: 8.3488 - val_y1_output_loss: 1.3493 - val_y2_output_loss: 7.2118 - val_y1_output_root_mean_squared_error: 1.1462 - val_y2_output_root_mean_squared_error: 2.6524
# Epoch 109/800
# 614/614 [==============================] - 0s 142us/sample - loss: 2.0037 - y1_output_loss: 0.4546 - y2_output_loss: 1.5453 - y1_output_root_mean_squared_error: 0.6729 - y2_output_root_mean_squared_error: 1.2454 - val_loss: 3.6579 - val_y1_output_loss: 0.8281 - val_y2_output_loss: 2.7579 - val_y1_output_root_mean_squared_error: 0.9004 - val_y2_output_root_mean_squared_error: 1.6874
# Epoch 110/800
# 614/614 [==============================] - 0s 154us/sample - loss: 2.2241 - y1_output_loss: 0.5031 - y2_output_loss: 1.7014 - y1_output_root_mean_squared_error: 0.7124 - y2_output_root_mean_squared_error: 1.3102 - val_loss: 2.6216 - val_y1_output_loss: 0.6116 - val_y2_output_loss: 1.9566 - val_y1_output_root_mean_squared_error: 0.7836 - val_y2_output_root_mean_squared_error: 1.4169
# Epoch 111/800
# 614/614 [==============================] - 0s 142us/sample - loss: 2.2006 - y1_output_loss: 0.5290 - y2_output_loss: 1.6536 - y1_output_root_mean_squared_error: 0.7291 - y2_output_root_mean_squared_error: 1.2919 - val_loss: 2.5594 - val_y1_output_loss: 0.5667 - val_y2_output_loss: 1.9458 - val_y1_output_root_mean_squared_error: 0.7554 - val_y2_output_root_mean_squared_error: 1.4102
# Epoch 112/800
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1730 - y1_output_loss: 0.4701 - y2_output_loss: 1.6886 - y1_output_root_mean_squared_error: 0.6878 - y2_output_root_mean_squared_error: 1.3038 - val_loss: 3.9174 - val_y1_output_loss: 1.2033 - val_y2_output_loss: 2.6265 - val_y1_output_root_mean_squared_error: 1.0937 - val_y2_output_root_mean_squared_error: 1.6496
# Epoch 113/800
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0600 - y1_output_loss: 0.4437 - y2_output_loss: 1.5993 - y1_output_root_mean_squared_error: 0.6683 - y2_output_root_mean_squared_error: 1.2702 - val_loss: 3.1053 - val_y1_output_loss: 0.7054 - val_y2_output_loss: 2.3823 - val_y1_output_root_mean_squared_error: 0.8380 - val_y2_output_root_mean_squared_error: 1.5501
# Epoch 114/800
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7241 - y1_output_loss: 0.6524 - y2_output_loss: 2.0510 - y1_output_root_mean_squared_error: 0.8105 - y2_output_root_mean_squared_error: 1.4378 - val_loss: 2.7084 - val_y1_output_loss: 0.6498 - val_y2_output_loss: 1.9921 - val_y1_output_root_mean_squared_error: 0.8151 - val_y2_output_root_mean_squared_error: 1.4297
# Epoch 115/800
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4778 - y1_output_loss: 0.8217 - y2_output_loss: 2.6308 - y1_output_root_mean_squared_error: 0.9085 - y2_output_root_mean_squared_error: 1.6286 - val_loss: 3.7463 - val_y1_output_loss: 1.1233 - val_y2_output_loss: 2.6834 - val_y1_output_root_mean_squared_error: 1.0381 - val_y2_output_root_mean_squared_error: 1.6336
# Epoch 116/800
# 614/614 [==============================] - 0s 144us/sample - loss: 1.9932 - y1_output_loss: 0.4291 - y2_output_loss: 1.6264 - y1_output_root_mean_squared_error: 0.6460 - y2_output_root_mean_squared_error: 1.2554 - val_loss: 21.2168 - val_y1_output_loss: 9.0594 - val_y2_output_loss: 12.8881 - val_y1_output_root_mean_squared_error: 2.9558 - val_y2_output_root_mean_squared_error: 3.5327
# Epoch 117/800
# 614/614 [==============================] - 0s 149us/sample - loss: 4.0746 - y1_output_loss: 1.3331 - y2_output_loss: 2.7164 - y1_output_root_mean_squared_error: 1.1598 - y2_output_root_mean_squared_error: 1.6521 - val_loss: 2.7422 - val_y1_output_loss: 0.6572 - val_y2_output_loss: 1.9952 - val_y1_output_root_mean_squared_error: 0.8195 - val_y2_output_root_mean_squared_error: 1.4389
# Epoch 118/800
# 614/614 [==============================] - 0s 146us/sample - loss: 2.2249 - y1_output_loss: 0.5216 - y2_output_loss: 1.7072 - y1_output_root_mean_squared_error: 0.7215 - y2_output_root_mean_squared_error: 1.3055 - val_loss: 6.8891 - val_y1_output_loss: 1.4124 - val_y2_output_loss: 5.4202 - val_y1_output_root_mean_squared_error: 1.2043 - val_y2_output_root_mean_squared_error: 2.3321
# Epoch 119/800
# 614/614 [==============================] - 0s 139us/sample - loss: 1.8075 - y1_output_loss: 0.4032 - y2_output_loss: 1.4168 - y1_output_root_mean_squared_error: 0.6332 - y2_output_root_mean_squared_error: 1.1860 - val_loss: 3.5696 - val_y1_output_loss: 0.8468 - val_y2_output_loss: 2.6589 - val_y1_output_root_mean_squared_error: 0.9102 - val_y2_output_root_mean_squared_error: 1.6556
# Epoch 120/800
# 614/614 [==============================] - 0s 137us/sample - loss: 2.1669 - y1_output_loss: 0.5119 - y2_output_loss: 1.6432 - y1_output_root_mean_squared_error: 0.7142 - y2_output_root_mean_squared_error: 1.2872 - val_loss: 2.8732 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 1.9538 - val_y1_output_root_mean_squared_error: 0.9357 - val_y2_output_root_mean_squared_error: 1.4134
# Epoch 121/800
# ...
# Epoch 761/800
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1973 - y1_output_loss: 0.0675 - y2_output_loss: 0.1310 - y1_output_root_mean_squared_error: 0.2608 - y2_output_root_mean_squared_error: 0.3596 - val_loss: 0.7564 - val_y1_output_loss: 0.2466 - val_y2_output_loss: 0.5277 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.7187
# Epoch 762/800
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1653 - y1_output_loss: 0.0627 - y2_output_loss: 0.1022 - y1_output_root_mean_squared_error: 0.2502 - y2_output_root_mean_squared_error: 0.3204 - val_loss: 0.6487 - val_y1_output_loss: 0.2684 - val_y2_output_loss: 0.3865 - val_y1_output_root_mean_squared_error: 0.5125 - val_y2_output_root_mean_squared_error: 0.6213
# Epoch 763/800
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2006 - y1_output_loss: 0.0723 - y2_output_loss: 0.1267 - y1_output_root_mean_squared_error: 0.2701 - y2_output_root_mean_squared_error: 0.3573 - val_loss: 0.6068 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.3959 - val_y1_output_root_mean_squared_error: 0.4450 - val_y2_output_root_mean_squared_error: 0.6393
# Epoch 764/800
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2032 - y1_output_loss: 0.0723 - y2_output_loss: 0.1301 - y1_output_root_mean_squared_error: 0.2689 - y2_output_root_mean_squared_error: 0.3618 - val_loss: 0.6536 - val_y1_output_loss: 0.2370 - val_y2_output_loss: 0.4054 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 0.6435
# Epoch 765/800
# 614/614 [==============================] - 0s 148us/sample - loss: 0.1626 - y1_output_loss: 0.0665 - y2_output_loss: 0.0970 - y1_output_root_mean_squared_error: 0.2577 - y2_output_root_mean_squared_error: 0.3102 - val_loss: 0.7232 - val_y1_output_loss: 0.2261 - val_y2_output_loss: 0.4755 - val_y1_output_root_mean_squared_error: 0.4819 - val_y2_output_root_mean_squared_error: 0.7006
# Epoch 766/800
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1684 - y1_output_loss: 0.0628 - y2_output_loss: 0.1048 - y1_output_root_mean_squared_error: 0.2508 - y2_output_root_mean_squared_error: 0.3248 - val_loss: 0.5917 - val_y1_output_loss: 0.2112 - val_y2_output_loss: 0.3664 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 0.6128
# Epoch 767/800
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2079 - y1_output_loss: 0.0685 - y2_output_loss: 0.1403 - y1_output_root_mean_squared_error: 0.2618 - y2_output_root_mean_squared_error: 0.3733 - val_loss: 1.0551 - val_y1_output_loss: 0.2328 - val_y2_output_loss: 0.7915 - val_y1_output_root_mean_squared_error: 0.4857 - val_y2_output_root_mean_squared_error: 0.9051
# Epoch 768/800
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1884 - y1_output_loss: 0.0659 - y2_output_loss: 0.1214 - y1_output_root_mean_squared_error: 0.2570 - y2_output_root_mean_squared_error: 0.3498 - val_loss: 0.5852 - val_y1_output_loss: 0.2096 - val_y2_output_loss: 0.3691 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.6133
# Epoch 769/800
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2654 - y1_output_loss: 0.0773 - y2_output_loss: 0.2150 - y1_output_root_mean_squared_error: 0.2728 - y2_output_root_mean_squared_error: 0.4370 - val_loss: 8.0539 - val_y1_output_loss: 1.9876 - val_y2_output_loss: 6.2605 - val_y1_output_root_mean_squared_error: 1.3883 - val_y2_output_root_mean_squared_error: 2.4752
# Epoch 770/800
# 614/614 [==============================] - 0s 146us/sample - loss: 1.1455 - y1_output_loss: 0.2578 - y2_output_loss: 0.8795 - y1_output_root_mean_squared_error: 0.5087 - y2_output_root_mean_squared_error: 0.9417 - val_loss: 0.7318 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 0.4750 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.7014
# Epoch 771/800
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1948 - y1_output_loss: 0.0709 - y2_output_loss: 0.1229 - y1_output_root_mean_squared_error: 0.2663 - y2_output_root_mean_squared_error: 0.3520 - val_loss: 0.6267 - val_y1_output_loss: 0.2332 - val_y2_output_loss: 0.3834 - val_y1_output_root_mean_squared_error: 0.4867 - val_y2_output_root_mean_squared_error: 0.6243
# Epoch 772/800
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1788 - y1_output_loss: 0.0717 - y2_output_loss: 0.1062 - y1_output_root_mean_squared_error: 0.2684 - y2_output_root_mean_squared_error: 0.3268 - val_loss: 0.5440 - val_y1_output_loss: 0.2023 - val_y2_output_loss: 0.3312 - val_y1_output_root_mean_squared_error: 0.4525 - val_y2_output_root_mean_squared_error: 0.5824
# Epoch 773/800
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1799 - y1_output_loss: 0.0708 - y2_output_loss: 0.1107 - y1_output_root_mean_squared_error: 0.2644 - y2_output_root_mean_squared_error: 0.3316 - val_loss: 0.9430 - val_y1_output_loss: 0.2326 - val_y2_output_loss: 0.6804 - val_y1_output_root_mean_squared_error: 0.4875 - val_y2_output_root_mean_squared_error: 0.8398
# Epoch 774/800
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2008 - y1_output_loss: 0.0738 - y2_output_loss: 0.1265 - y1_output_root_mean_squared_error: 0.2710 - y2_output_root_mean_squared_error: 0.3569 - val_loss: 0.6501 - val_y1_output_loss: 0.2330 - val_y2_output_loss: 0.3999 - val_y1_output_root_mean_squared_error: 0.4879 - val_y2_output_root_mean_squared_error: 0.6420
# Epoch 775/800
# 614/614 [==============================] - 0s 152us/sample - loss: 0.2182 - y1_output_loss: 0.0768 - y2_output_loss: 0.1406 - y1_output_root_mean_squared_error: 0.2778 - y2_output_root_mean_squared_error: 0.3755 - val_loss: 0.5995 - val_y1_output_loss: 0.2269 - val_y2_output_loss: 0.3775 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.6115
# Epoch 776/800
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1860 - y1_output_loss: 0.0662 - y2_output_loss: 0.1194 - y1_output_root_mean_squared_error: 0.2574 - y2_output_root_mean_squared_error: 0.3461 - val_loss: 0.7346 - val_y1_output_loss: 0.2541 - val_y2_output_loss: 0.4627 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_root_mean_squared_error: 0.6906
# Epoch 777/800
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1910 - y1_output_loss: 0.0735 - y2_output_loss: 0.1191 - y1_output_root_mean_squared_error: 0.2702 - y2_output_root_mean_squared_error: 0.3436 - val_loss: 1.2309 - val_y1_output_loss: 0.3825 - val_y2_output_loss: 0.8184 - val_y1_output_root_mean_squared_error: 0.6239 - val_y2_output_root_mean_squared_error: 0.9175
# Epoch 778/800
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2172 - y1_output_loss: 0.0769 - y2_output_loss: 0.1399 - y1_output_root_mean_squared_error: 0.2772 - y2_output_root_mean_squared_error: 0.3746 - val_loss: 0.6894 - val_y1_output_loss: 0.2913 - val_y2_output_loss: 0.4015 - val_y1_output_root_mean_squared_error: 0.5356 - val_y2_output_root_mean_squared_error: 0.6344
# Epoch 779/800
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1829 - y1_output_loss: 0.0710 - y2_output_loss: 0.1119 - y1_output_root_mean_squared_error: 0.2659 - y2_output_root_mean_squared_error: 0.3350 - val_loss: 0.6935 - val_y1_output_loss: 0.2358 - val_y2_output_loss: 0.4449 - val_y1_output_root_mean_squared_error: 0.4860 - val_y2_output_root_mean_squared_error: 0.6762
# Epoch 780/800
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1664 - y1_output_loss: 0.0707 - y2_output_loss: 0.0960 - y1_output_root_mean_squared_error: 0.2658 - y2_output_root_mean_squared_error: 0.3095 - val_loss: 1.1449 - val_y1_output_loss: 0.3448 - val_y2_output_loss: 0.8220 - val_y1_output_root_mean_squared_error: 0.5805 - val_y2_output_root_mean_squared_error: 0.8989
# Epoch 781/800
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2006 - y1_output_loss: 0.0664 - y2_output_loss: 0.1336 - y1_output_root_mean_squared_error: 0.2572 - y2_output_root_mean_squared_error: 0.3666 - val_loss: 0.7344 - val_y1_output_loss: 0.2378 - val_y2_output_loss: 0.4732 - val_y1_output_root_mean_squared_error: 0.4942 - val_y2_output_root_mean_squared_error: 0.7001
# Epoch 782/800
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1620 - y1_output_loss: 0.0669 - y2_output_loss: 0.0939 - y1_output_root_mean_squared_error: 0.2594 - y2_output_root_mean_squared_error: 0.3077 - val_loss: 0.5573 - val_y1_output_loss: 0.2190 - val_y2_output_loss: 0.3326 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 0.5840
# Epoch 783/800
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1966 - y1_output_loss: 0.0697 - y2_output_loss: 0.1256 - y1_output_root_mean_squared_error: 0.2644 - y2_output_root_mean_squared_error: 0.3560 - val_loss: 0.6078 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 0.3929 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.6320
# Epoch 784/800
# 614/614 [==============================] - 0s 151us/sample - loss: 0.2527 - y1_output_loss: 0.0805 - y2_output_loss: 0.1711 - y1_output_root_mean_squared_error: 0.2848 - y2_output_root_mean_squared_error: 0.4142 - val_loss: 0.6277 - val_y1_output_loss: 0.2530 - val_y2_output_loss: 0.3680 - val_y1_output_root_mean_squared_error: 0.5030 - val_y2_output_root_mean_squared_error: 0.6121
# Epoch 785/800
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1850 - y1_output_loss: 0.0760 - y2_output_loss: 0.1089 - y1_output_root_mean_squared_error: 0.2760 - y2_output_root_mean_squared_error: 0.3299 - val_loss: 0.5710 - val_y1_output_loss: 0.2135 - val_y2_output_loss: 0.3463 - val_y1_output_root_mean_squared_error: 0.4643 - val_y2_output_root_mean_squared_error: 0.5962
# Epoch 786/800
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2100 - y1_output_loss: 0.0806 - y2_output_loss: 0.1277 - y1_output_root_mean_squared_error: 0.2852 - y2_output_root_mean_squared_error: 0.3587 - val_loss: 0.5900 - val_y1_output_loss: 0.2382 - val_y2_output_loss: 0.3466 - val_y1_output_root_mean_squared_error: 0.4845 - val_y2_output_root_mean_squared_error: 0.5961
# Epoch 787/800
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2131 - y1_output_loss: 0.0726 - y2_output_loss: 0.1396 - y1_output_root_mean_squared_error: 0.2699 - y2_output_root_mean_squared_error: 0.3745 - val_loss: 0.7314 - val_y1_output_loss: 0.2469 - val_y2_output_loss: 0.4936 - val_y1_output_root_mean_squared_error: 0.4931 - val_y2_output_root_mean_squared_error: 0.6987
# Epoch 788/800
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1899 - y1_output_loss: 0.0660 - y2_output_loss: 0.1231 - y1_output_root_mean_squared_error: 0.2574 - y2_output_root_mean_squared_error: 0.3516 - val_loss: 0.5596 - val_y1_output_loss: 0.2124 - val_y2_output_loss: 0.3390 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 0.5897
# Epoch 789/800
# 614/614 [==============================] - 0s 145us/sample - loss: 0.1660 - y1_output_loss: 0.0617 - y2_output_loss: 0.1049 - y1_output_root_mean_squared_error: 0.2482 - y2_output_root_mean_squared_error: 0.3231 - val_loss: 0.6234 - val_y1_output_loss: 0.2624 - val_y2_output_loss: 0.3589 - val_y1_output_root_mean_squared_error: 0.5108 - val_y2_output_root_mean_squared_error: 0.6020
# Epoch 790/800
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1641 - y1_output_loss: 0.0674 - y2_output_loss: 0.0955 - y1_output_root_mean_squared_error: 0.2606 - y2_output_root_mean_squared_error: 0.3100 - val_loss: 0.5461 - val_y1_output_loss: 0.1956 - val_y2_output_loss: 0.3382 - val_y1_output_root_mean_squared_error: 0.4460 - val_y2_output_root_mean_squared_error: 0.5892
# Epoch 791/800
# 614/614 [==============================] - 0s 153us/sample - loss: 0.1594 - y1_output_loss: 0.0657 - y2_output_loss: 0.0955 - y1_output_root_mean_squared_error: 0.2569 - y2_output_root_mean_squared_error: 0.3056 - val_loss: 0.6448 - val_y1_output_loss: 0.2263 - val_y2_output_loss: 0.4170 - val_y1_output_root_mean_squared_error: 0.4755 - val_y2_output_root_mean_squared_error: 0.6471
# Epoch 792/800
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1804 - y1_output_loss: 0.0733 - y2_output_loss: 0.1073 - y1_output_root_mean_squared_error: 0.2714 - y2_output_root_mean_squared_error: 0.3266 - val_loss: 0.6414 - val_y1_output_loss: 0.2168 - val_y2_output_loss: 0.4082 - val_y1_output_root_mean_squared_error: 0.4692 - val_y2_output_root_mean_squared_error: 0.6490
# Epoch 793/800
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2114 - y1_output_loss: 0.0690 - y2_output_loss: 0.1410 - y1_output_root_mean_squared_error: 0.2631 - y2_output_root_mean_squared_error: 0.3771 - val_loss: 0.5665 - val_y1_output_loss: 0.2366 - val_y2_output_loss: 0.3270 - val_y1_output_root_mean_squared_error: 0.4828 - val_y2_output_root_mean_squared_error: 0.5774
# Epoch 794/800
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1842 - y1_output_loss: 0.0686 - y2_output_loss: 0.1235 - y1_output_root_mean_squared_error: 0.2597 - y2_output_root_mean_squared_error: 0.3417 - val_loss: 1.2125 - val_y1_output_loss: 0.2896 - val_y2_output_loss: 0.8937 - val_y1_output_root_mean_squared_error: 0.5378 - val_y2_output_root_mean_squared_error: 0.9608
# Epoch 795/800
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2635 - y1_output_loss: 0.0766 - y2_output_loss: 0.1902 - y1_output_root_mean_squared_error: 0.2777 - y2_output_root_mean_squared_error: 0.4317 - val_loss: 0.8466 - val_y1_output_loss: 0.2748 - val_y2_output_loss: 0.5616 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.7549
# Epoch 796/800
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3875 - y1_output_loss: 0.1360 - y2_output_loss: 0.2483 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 0.5684 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.3516 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 0.5971
# Epoch 797/800
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1957 - y1_output_loss: 0.0722 - y2_output_loss: 0.1225 - y1_output_root_mean_squared_error: 0.2693 - y2_output_root_mean_squared_error: 0.3510 - val_loss: 0.7010 - val_y1_output_loss: 0.2525 - val_y2_output_loss: 0.4495 - val_y1_output_root_mean_squared_error: 0.5056 - val_y2_output_root_mean_squared_error: 0.6673
# Epoch 798/800
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1919 - y1_output_loss: 0.0695 - y2_output_loss: 0.1213 - y1_output_root_mean_squared_error: 0.2639 - y2_output_root_mean_squared_error: 0.3496 - val_loss: 0.5556 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.3390 - val_y1_output_root_mean_squared_error: 0.4598 - val_y2_output_root_mean_squared_error: 0.5867
# Epoch 799/800
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1864 - y1_output_loss: 0.0700 - y2_output_loss: 0.1153 - y1_output_root_mean_squared_error: 0.2653 - y2_output_root_mean_squared_error: 0.3406 - val_loss: 0.5540 - val_y1_output_loss: 0.2175 - val_y2_output_loss: 0.3266 - val_y1_output_root_mean_squared_error: 0.4687 - val_y2_output_root_mean_squared_error: 0.5782
# Epoch 800/800
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2373 - y1_output_loss: 0.0836 - y2_output_loss: 0.1554 - y1_output_root_mean_squared_error: 0.2853 - y2_output_root_mean_squared_error: 0.3948 - val_loss: 0.6280 - val_y1_output_loss: 0.2440 - val_y2_output_loss: 0.3863 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.6251

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 39us/sample - loss: 0.6280 - y1_output_loss: 0.2382 - y2_output_loss: 0.3932 - y1_output_root_mean_squared_error: 0.4871 - y2_output_root_mean_squared_error: 0.6251
# Loss = 0.62803996538187, Y1_loss = 0.23824374377727509, Y1_mse = 0.4871003329753876, Y2_loss = 0.3932422399520874, Y2_mse = 0.6251185536384583

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
